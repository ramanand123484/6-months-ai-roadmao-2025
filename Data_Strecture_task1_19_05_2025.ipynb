# %% [markdown]
# # List

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
l.append(10)
l.append(20)

# %%
l
# Out:
# [10, 20]

# %%
l.append(30)
l.append(40)
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 10]

# %%
len(l)
# Out:
# 5

# %%
l10=[]

# %%
l10=l.copy()

# %%
l10
# Out:
# [10, 20, 30, 40, 10]

# %%
l==l10
# Out:
# True

# %%
print(l)
print(l10)
# Out:
# [10, 20, 30, 40, 10]
# [10, 20, 30, 40, 10]

# %%
l10
# Out:
# [10, 20, 30, 40, 10]

# %%
l9=[]

# %%
l9.append(2.3)
l9.append('nit')
l9.append(True)
l9.append(1+2j)
l9.append([1,2,3])
l9
# Out:
# [2.3, 'nit', True, (1+2j), [1, 2, 3]]

# %%
print(l)
print(l10)
print(l9)
# Out:
# [10, 20, 30, 40, 10]
# [10, 20, 30, 40, 10]
# [2.3, 'nit', True, (1+2j), [1, 2, 3]]

# %%
print(len(l))
print(len(l10))
print(len(l9))
# Out:
# 5
# 5
# 5

# %%
print(id(l))
print(id(l10))
print(id(l9))
# Out:
# 137199111293824
# 137199494774912
# 137199117163456

# %%
l.count(20)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l9.count('nit')
# Out:
# 1

# %% [markdown]
# # 1)list inside list is called as nested list
# # 2)for inside for is called as nested for
# # 3)while inside while is called as nested while loop

# %% [markdown]
# # forward indexing 👇

# %%
l9[0]
# Out:
# 2.3

# %%
l9[1]
# Out:
# 'nit'

# %%
l9[2]
# Out:
# True

# %%
l9[3]
# Out:
# (1+2j)

# %%
l9[4]
# Out:
# [1, 2, 3]

# %% [markdown]
# # Backward Indexing👇

# %%
l9[-1]
# Out:
# [1, 2, 3]

# %%
l9[-2]
# Out:
# (1+2j)

# %%
l9[-3]
# Out:
# True

# %%
l9[-4]
# Out:
# 'nit'

# %%
l9[-5]
# Out:
# 2.3

# %% [markdown]
# # Mutable=changable👇
# #list is mutable

# %%
l9[0]=230

# %%
l9
# Out:
# [230, 'nit', True, (1+2j), [1, 2, 3]]

# %%
l10
# Out:
# [10, 20, 30, 40, 10]

# %%
len(l10)
# Out:
# 5

# %%
l10.clear()

# %%
l10
# Out:
# []

# %%
len(l10)
# Out:
# 0

# %%
del l10

# %%
l10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1555538318.py in <cell line: 0>()
# ----> 1 l10
#
# NameError: name 'l10' is not defined

# %%
l9
# Out:
# [230, 'nit', True, (1+2j), [1, 2, 3]]

# %%
l9.pop()
# Out:
# [1, 2, 3]

# %%
l9
# Out:
# [230, 'nit', True, (1+2j)]

# %%
l9.pop(1)
# Out:
# 'nit'

# %%
l9
# Out:
# [230, True, (1+2j)]

# %% [markdown]
# # 1)the pop() function removes the value by index  by default last index
# # end of the list element
# # 2) if user want to remove any specific element then specific index has to enter

# %%
l1=[]
l1
# Out:
# []

# %%
l1.append('nit')
l1.append('True')
l1.append('2.3')
l1.append('1+2j')
l1.append([1,2,3])
l1.append('mit')

# %%
l1
# Out:
# ['nit', 'True', '2.3', '1+2j', [1, 2, 3], 'mit']

# %%
l1.remove('True')

# %%
l1
# Out:
# ['nit', '2.3', '1+2j', [1, 2, 3], 'mit']

# %%
l1
# Out:
# ['nit', '2.3', '1+2j', [1, 2, 3], 'mit']

# %%
l1.remove([1,2,3])
l1
# Out:
# ['nit', '2.3', '1+2j', 'mit']
