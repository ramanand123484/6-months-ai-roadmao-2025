# %%
l=[]
l
# Out:
# []

# %% [markdown]
# #1)You can not append(add) many element at a time👆

# %%
l.append(10)
l.append(20)
l.append(30)
l.append(2.3)
l.append(4.6)
l.append('nit')
l.append(1+2j)
l.append(True)

# %%
l
# Out:
# [10, 20, 30, 2.3, 4.6, 'nit', (1+2j), True]

# %%
len(l)
# Out:
# 8

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l.index('nit')
# Out:
# 5

# %%
l[5]
# Out:
# 'nit'

# %%
print(l[5][0]) # nested list list in the list
print(l[5][1])
print(l[5][2])
# Out:
# n
# i
# t

# %%
l
# Out:
# [10, 20, 30, 2.3, 4.6, 'nit', (1+2j), True]

# %%
for i in l:
  print(i)
# Out:
# 10
# 20
# 30
# 2.3
# 4.6
# nit
# (1+2j)
# True

# %%
l
# Out:
# [10, 20, 30, 2.3, 4.6, 'nit', (1+2j), True]

# %%
l.pop()
# Out:
# True

# %%
l.pop(2)
# Out:
# 30

# %%
l
# Out:
# [10, 20, 2.3, 4.6, 'nit', (1+2j)]

# %%
l.remove(1+2j)

# %%
l
# Out:
# [10, 20, 2.3, 4.6, 'nit']

# %%
l[:10]
# Out:
# [10, 20, 2.3, 4.6, 'nit']

# %% [markdown]
# # list is mutable means you can change the value any time

# %% [markdown]
# # list is completed
