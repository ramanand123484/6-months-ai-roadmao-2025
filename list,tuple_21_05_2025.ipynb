# %%
l = [1,2,3]
l
# Out:
# [1, 2, 3]

# %%
l.sort()
l
# Out:
# [1, 2, 3]

# %%
l1=[20,9,3,100]
l1
# Out:
# [20, 9, 3, 100]

# %%
l1.sort()

# %%
l1
# Out:
# [3, 9, 20, 100]

# %%
l2=['a',3,3.4,1+2j]
l2
# Out:
# ['a', 3, 3.4, (1+2j)]

# %%
l2.sort() #we can not sort in mix datatype like string,interger,float,complex,boolean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4124864166.py in <cell line: 0>()
# ----> 1 l2.sort() #we can not sort in mix datatype like string,interger,float,complex,boolean
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
l3=['z','m','a','d']
l3
# Out:
# ['z', 'm', 'a', 'd']

# %%
l3.sort()

# %%
l3
# Out:
# ['a', 'd', 'm', 'z']

# %%
l3.reverse()

# %%
l3
# Out:
# ['z', 'm', 'd', 'a']

# %%
l1
# Out:
# [3, 9, 20, 100]

# %%
l1.sort(reverse=True)

# %%
l1
# Out:
# [100, 20, 9, 3]

# %%
l.append('nit')
l
# Out:
# [1, 2, 3, 'nit']

# %%
l[3]
# Out:
# 'nit'

# %%
print(l[3][0])
print(l[3][1])
print(l[3][2])

#index in the index is called nested index
# nested index only work with string
# Out:
# n
# i
# t

# %%
l
# Out:
# [1, 2, 3, 'nit']

# %%
for i in l:
  print(i) # i means iteration
# Out:
# 1
# 2
# 3
# nit

# %%
for i in enumerate(l):
  print(i)  #shift + Tab is working in jupiternotebook not in google colab for help
# Out:
# (0, 1)
# (1, 2)
# (2, 3)
# (3, 'nit')

# %%
l3
# Out:
# ['z', 'm', 'd', 'a']

# %%
for j in enumerate(l3):
  print(j)
# Out:
# (0, 'z')
# (1, 'm')
# (2, 'd')
# (3, 'a')

# %%
 # we complete list datastrecture

# %%
l
# Out:
# [1, 2, 3, 'nit']

# %%
all(l)
# Out:
# True

# %%
any(l)
# Out:
# True

# %%
l.append(0)

# %%
l
# Out:
# [1, 2, 3, 'nit', 0]

# %%
all(l) # Returns false as one value is false
# Out:
# False

# %%
any(l) # Will Return True as we have items in the list with True value.
# Out:
# True

# %% [markdown]
# # list has completed

# %% [markdown]
# # Start the tuple

# %%
t=()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,20,30,40,10) # duplicate is allowed in tuple

# %%
t1
# Out:
# (10, 20, 30, 40, 10)

# %%
t1.index(20)
# Out:
# 1

# %%
t1.index(40)
# Out:
# 3

# %%
t1.count(10)
# Out:
# 2

# %%
t1.count(20)
# Out:
# 1

# %%
t2=t1*2

# %%
t2
# Out:
# (10, 20, 30, 40, 10, 10, 20, 30, 40, 10)

# %%
icici=(1234,'pan ciz1081n',6798)

# %%
icici
# Out:
# (1234, 'pan ciz1081n', 6798)

# %%
t1[0]
# Out:
# 10

# %%
t1[0]=100 # tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-469800251.py in <cell line: 0>()
# ----> 1 t1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
l
# Out:
# [1, 2, 3, 'nit', 0]

# %%
l[-1]=0.3 # list is mutable
l
# Out:
# [1, 2, 3, 'nit', 0.3]

# %%
t2=([1,2,3],34,5.6) #tuple inside tuple is called nested tuple

# %%
t2
# Out:
# ([1, 2, 3], 34, 5.6)

# %%
len(t2)
# Out:
# 3

# %% [markdown]
# # tuple has completed
